# %% [markdown]
# # Welcome to IRuta Notebooks!

# %% [markdown]
# An IRuta Notebook is a Notebook that allows execute [UIMA Ruta](http://uima.apache.org/ruta.html) code. Ruta is a rule-based language for quickly adding and removing annotations to a document. In that context, an annotation is simply an annotated text span which holds information about the position (begin/end) and other features (e.g. a count, a category, etc.).

# %% [markdown]
# ### Why using IRuta Notebooks?
# - ✅ Easy to set up
# - ✅ Allow for a rapid iterative development of Ruta rules
# - ✅ Full support of Ruta functionality (including loading of resources, typesystem and reading input files as single CAS or in batch mode)
# - ✅ Extensive IDE support
#     - Syntax Highlighting is automatically working.
#     - *Hint 1*: Autocompletion can be trigged by start typing and pressing the `Tab` key.
#     - *Hint 2*: Documentation for functions can be accessed by pressing `Shift` + `Tab`.
# - ✅ Can be combined with markdown to create a self-explanatory scripts
# - ✅ Can easily be combined with Python in the same Notebook

# %% [markdown]
# ---
# # A first example: Annotating names

# %% [markdown]
# IRuta Notebooks have two major components:
# 1. When a code cell is executed in this notebook, then its content is interpret by an IRuta kernel.
# 2. On top of the IRuta Kernel, there are so-called *magic commands* that allow interacting with the kernel.

# %% [markdown]
# #### 1. (CellMagic) Settings the document text

# %%
%%documentText 
Anna likes to play football.
Bryan eats a sandwich.

# %% [markdown]
# #### 2. (Ruta) Delcaring a new type in Ruta

# %%
 DECLARE Name;
# Out:
# Anna likes to play football.<br />Bryan eats a sandwich.

# %% [markdown]
# #### 3. (Ruta) Annotating names

# %%
"Anna" -> Name;
# Out:
# Anna likes to play football.<br />Bryan eats a sandwich.

# %% [markdown]
# #### 4. (Ruta) The annotation is not yet visible. We need to highlight it using `COLOR()`

# %%
COLOR(Name,"lightgreen");
# Out:
# <span style='background:#90ee90'>Anna</span> likes to play football.<br />Bryan eats a sandwich.

# %% [markdown]
# #### 5. (Ruta) Annotate another name.

# %%
"Bryan" -> Name;
# Out:
# <span style='background:#90ee90'>Anna</span> likes to play football.<br /><span style='background:#90ee90'>Bryan</span> eats a sandwich.

# %% [markdown]
# # A second example: Detecting negations for medical problems

# %% [markdown]
# #### 1. (CellMagic) Set document text

# %%
%%documentText 
Patient has severe headache and nausea. 
He denies fevers, chills or sweats.

# %% [markdown]
# #### 2. (Ruta) Detecting negations for medical problems

# %%
DECLARE Problem, NoProblem;
DECLARE NegationCue;
DECLARE Conj, Sentence, ProblemEnumeration;

// Mock annotations
"fevers?|chills?|sweats?|headache|nausea" -> Problem;
"deny|denies" -> NegationCue;
"and|or" -> Conj;

// Detect enumerations
ANY+{-PARTOF(Sentence),-PARTOF(PERIOD)-> Sentence};
(Problem (COMMA Problem)* Conj Problem){-> ProblemEnumeration};

// Find negations and apply them to enumeration
Sentence{CONTAINS(Problem)} -> {
    cue:NegationCue # ProblemEnumeration 
        ->{p:@Problem{-> UNMARK(p), NoProblem};};
    };

// Coloring specific annotations
COLOR(Problem, "red");
COLOR(NoProblem, "lightgreen");
# Out:
# Patient has severe <span style='background:#ff0000'>headache</span> and <span style='background:#ff0000'>nausea</span>. <br />He denies <span style='background:#90ee90'>fevers</span>, <span style='background:#90ee90'>chills</span> or <span style='background:#90ee90'>sweats</span>.

# %% [markdown]
# ---

# %% [markdown]
# # Advanced topics

# %% [markdown]
# ## Topic 1: Important magics
# So-called *magics* are used for communicating with the IRuta kernel. They allow settings a variety of parameters or triggering specific actions. Please see the list of the most important magics.
# - `%documentText [text]`: Sets the text of the Cas, optionally also takes a language parameters, i.e. ```%documentText en "my great covered text".```
# - `%loadCas [path]`: Loads a Cas from a path
# - `%inputDir [directory]`: Sets the input directory
# - `%outputDir [directory]`: Sets the output directory
# - `%typeSystemDir [directory]`: Sets the path of the descriptors (e.g. for loading external TypeSystems)
# - `%resourceDir [directory]`: Sets the path of the ressources (e.g. wordlists)
# - `%scriptPaths [directory]`: Sets the path for loading auxillary Ruta scripts
# - `%displayMode [NONE|RUTA_COLORING|DYNAMIC_HTML|CSV]`: Determines the output format (see below for more information)
# - `%configParams [--key1=value1] [--key2=value2] ... `: Can be used to set parameters of the RutaEngine, e.g. whether strict imports are activated
# - `%writerules [directory]`: Writes the current cell to the specified directory (Ruta compatible, i.e. line magics are commented out).
#
# Please note that autocompletion also works on these magics.

# %% [markdown]
# ## Topic 2: Importing documents into the Common Analysis Structure (CAS)
# There are 3 options to load data into the Cas.

# %% [markdown]
# #### Option 1: Using `documentText` as cell or line magic

# %%
%%documentText en
This is my
great example text.

# %% [markdown]
# #### Option 2: Using `%loadCas` to load a single CAS from disk.

# %%
%loadCas input/xmi/short_example.xmi
# Out:
# Patient has severe stomachache and nausea. He denies any fevers, chills or sweats."

# %% [markdown]
# #### Option 3: Setting an input directory. This can be used for processing multiple files in batch mode.
# - Hint: `%displayMode NONE` suppresses the output.

# %%
%displayMode NONE
%inputDir input/xmi
# Out:
# Processed 3/3 files. (took 0s)

# %% [markdown]
# ## Topic 3: Files & Resource Loading
# - Files and resources can be loaded from disk
# - The paths can be adapted using the magic commands above

# %% [markdown]
# #### The example shows how to:
#    - load an existing TypeSystem (`description/MergedTypeSystem.xml`)
#    - loads the Cas (`input/xmi/example_en.xmi`)
#    - load an external wordlist (`wordlists/section_header.txt`) for marking section headers.

# %%
%displayMode RUTA_COLORING
%typeSystemDir typesystems/
%resourceDir wordlists/
%loadCas input/xmi/example_en.xmi
%outputDir output/
TYPESYSTEM MergedTypeSystem;
DECLARE DiagnosisInWrongSection;

// Mark all words from section_header.txt with the annotation type SectionHeader
DECLARE SectionHeader;
WORDLIST sectionHeader = 'section_header.txt';
MARKFAST(SectionHeader, sectionHeader);

Document{-> COLOR(Diagnosis, "yellow")};
Document{-> COLOR(SectionHeader, "green")};
# Out:
# <br /><span style='background:#008000'>ANAMNESIS</span><br /><br />Symptoms in the sense of <span style='background:#ffff00'>rest</span><span style='background:#ffff00'>less</span><span style='background:#ffff00'> </span><span style='background:#ffff00'>leg</span><span style='background:#ffff00'>s</span><span style='background:#ffff00'> </span><span style='background:#ffff00'>syndrom</span><span style='background:#ffff00'>e</span> were noted in the legs with tingling paresthesias. This had occurred especially with the intake of Isoptin. Blood pressure was now well controlled. The nocturnal CPAP therapy has helped. Occasionally, <span style='background:#ffff00'>angina</span><span style='background:#ffff00'> </span><span style='background:#ffff00'>pectoris</span> with left precordial pressure occurs regardless of exertion, although it is weather-dependent. No dizziness, occasional subjective heart <span style='background:#ffff00'>palpitations</span>.<br /><br /><span style='background:#008000'>EXAMINATION</span><span style='background:#008000'> </span><span style='background:#008000'>FIND</span><span style='background:#008000'>INGS</span><br /><br />Blood pressure normotensive at the time of examination, regular heartbeat sequence, no pathological auscultation findings over the heart. Pure 1st and 2nd heart sounds. Vesicular breathing on both sides. Supraaortic conduction vessels are clear. At the time of examination, discrete leg edema bilaterally, foot pulses palpable laterally with some limitation.<br /><br /><span style='background:#008000'>LABOR</span>: No significant pathological abnormalities, especially very good adjustment of total cholesterol.<br /><br /><span style='background:#008000'>ECG</span><br />Heart rate 63/min, sinus rhythm, indifferent type, T-flattening in aVL. Incomplete RSB.<br /><br /><span style='background:#008000'>DIAGNOSIS</span><br />Coronary artery disease, arterial <span style='background:#ffff00'>hypertens</span><span style='background:#ffff00'>ion</span>.<br /><br /><span style='background:#008000'>THERAPY</span><br />From the cardiac side, there is a pleasing constancy of findings.<br />With regard to the leg symptoms, the arteries and veins were unremarkable, so that an attempt to stop Isoptin was discussed. In case of borderline elevated pulmonary pressure, oxygen insufflation during the night is not necessary in addition to CPAP therapy. We request consultation and re-presentation in 14 days.<br />Increase medication from DILATREND 12.5 mg to 1-0-1.<br />

# %% [markdown]
# ## Topic 4: DisplayMode/ Cas Viewer
# - The easiest way of highlighting annotations is by using the Ruta function `COLOR()` in combination with `%displayMode RUTA_COLORING` (default) as demonstrated in the example above
# - A more advanced HTML/JS/CSS CasViewer can be activated using `%displayMode DYNAMIC_HTML`

# %%
%loadCas input/xmi/example_en.xmi
%displayMode DYNAMIC_HTML
# Out:
# <div class="annotation-viewer _418a7e5d-5cc1-4af9-8e1d-b43ecd208f15">
#   <script type="text/javascript">
#     var scriptBlock = document.currentScript;
#     var viewerBlock = $(scriptBlock).closest(".annotation-viewer");
#     require(["kernelspecs/ruta/annotations"], function (annotations) {
#       try {
#         annotations.onload(viewerBlock);
#       } catch (error) {
#         console.error(error);
#       }
#     });
#   </script>
# 	<style type="text/css">._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t3 .t3{color:white;background:black;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t3 .t3{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t3 .t3.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t23 .t23{color:black;background:coral;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t23 .t23{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t23 .t23.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t21 .t21{color:white;background:darkblue;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t21 .t21{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t21 .t21.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t34 .t34{color:white;background:darkmagenta;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t34 .t34{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t34 .t34.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t5 .t5{color:white;background:olive;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t5 .t5{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t5 .t5.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t46 .t46{color:black;background:lightblue;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t46 .t46{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t46 .t46.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t76 .t76{color:black;background:orange;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t76 .t76{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t76 .t76.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t27 .t27{color:black;background:yellow;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t27 .t27{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t27 .t27.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t75 .t75{color:black;background:pink;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t75 .t75{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t75 .t75.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t7 .t7{color:black;background:violet;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t7 .t7{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t7 .t7.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t8 .t8{color:black;background:tan;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t8 .t8{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t8 .t8.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t9 .t9{color:white;background:brown;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t9 .t9{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t9 .t9.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t10 .t10{color:white;background:green;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t10 .t10{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t10 .t10.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t35 .t35{color:white;background:olive;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t35 .t35{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t35 .t35.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t68 .t68{color:black;background:lightblue;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t68 .t68{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t68 .t68.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t39 .t39{color:white;background:olive;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t39 .t39{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t39 .t39.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t58 .t58{color:black;background:yellow;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t58 .t58{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t58 .t58.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t59 .t59{color:black;background:cyan;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t59 .t59{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t59 .t59.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t24 .t24{color:black;background:lightblue;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t24 .t24{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t24 .t24.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t80 .t80{color:white;background:mediumpurple;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t80 .t80{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t80 .t80.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t29 .t29{color:black;background:lightblue;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t29 .t29{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t29 .t29.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t69 .t69{color:white;background:blue;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t69 .t69{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t69 .t69.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t40 .t40{color:black;background:salmon;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t40 .t40{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t40 .t40.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t11 .t11{color:black;background:tan;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t11 .t11{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t11 .t11.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t12 .t12{color:white;background:brown;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t12 .t12{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t12 .t12.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t83 .t83{color:white;background:green;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t83 .t83{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t83 .t83.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t13 .t13{color:white;background:red;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t13 .t13{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t13 .t13.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t14 .t14{color:white;background:mediumpurple;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t14 .t14{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t14 .t14.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t37 .t37{color:white;background:darkblue;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t37 .t37{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t37 .t37.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t41 .t41{color:white;background:darkmagenta;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .text.t41 .t41{cursor:pointer;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .annotations.t41 .t41.inline-block{display:inline-block;}
# ._418a7e5d-5cc1-4af9-8e1d-b43ecd208f15 .t48 .t48{color:white;background:olive;}
# ._418a7e5d-5cc1-4a
